# %%
#Name:Shreyas Wani
#Prn:25070123131
#Experiment:16
#Aim: NLP Techniques on text data in python

# %%
#1.Tokenization
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

text = "Natural language processing is intresting"

tokens=word_tokenize(text)
print(tokens)
# Out:
# ['Natural', 'language', 'processing', 'is', 'intresting']

# %%
from nltk.tokenize import sent_tokenize

text = "Python is easy. It is widely used in data science."

sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Python is easy.', 'It is widely used in data science.']

# %%
#Stop word removal
#Stop words such as is,the,and,in are removed.

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

#text = "Python is easy. It is widely used in data science." #hamne yaha input nahi diya to usne prevous vaala input lai liya

words=word_tokenize(text)
filtered_words = [ w for w in words if w.lower() not in stop_words]

print(filtered_words)
print(stop_words)
# Out:
# ['Python', 'easy', '.', 'widely', 'used', 'data', 'science', '.']
# {"you'd", 'hers', 'which', 'hasn', "didn't", 'won', 'will', 're', 'own', 'in', 'why', 'against', 'now', 'they', 'off', 'there', "haven't", 'yours', 'she', 'on', 'don', "doesn't", "we'd", 'aren', 'and', 'my', 'it', 'her', 'ours', "it's", "it'd", 'll', 'he', 'more', 'needn', 'their', 'does', 'do', 'while', 'wouldn', 'same', "we'll", 'your', 'what', 'itself', 'about', 'at', 'few', "they're", 'where', 'up', "she'll", 'each', "you'll", 'from', 'but', 'didn', 'mustn', 'during', 'yourselves', "mightn't", 'then', 'how', 'those', "they'll", 'd', 'its', "aren't", 'shouldn', 'both', "it'll", 'most', 'ain', "that'll", 'further', 'just', 'the', "we've", 'can', 'herself', 'shan', 'so', 'other', "you're", 'with', 'into', 'having', 'himself', 'doing', "don't", 'no', "shan't", 'wasn', 'by', 'him', 'myself', 'when', 'ma', 'these', 'this', "they've", 'before', 'again', 'our', 'not', 'yourself', 'were', "mustn't", 'a', "i'd", 'very', 'been', 'whom', "weren't", 'below', "isn't", "i'm", "he'd", "she's", 'over', 'are', 'between', "i'll", 'was', 'mightn', "hasn't", 'i', 'nor', 'of', 'doesn', "you've", 'above', "she'd", "should've", "shouldn't", 'as', 'have', 'under', "i've", "hadn't", "he'll", 'haven', "couldn't", 'only', 'until', 'than', 'should', 'me', 'for', 'be', 'an', 'some', 'out', 'being', 'once', 't', 'you', 'through', "we're", 'who', 's', 'any', 'y', 'themselves', 'here', "he's", "wasn't", 'had', 'did', 'ourselves', "won't", 'hadn', 'because', 'after', "needn't", 'm', "they'd", 'weren', 'we', 'if', 'to', 'down', 'is', 'or', 'am', 'has', 'couldn', 'them', 'too', "wouldn't", 'such', 'all', 'that', 've', 'isn', 'o', 'theirs', 'his'}

# %%
#Stemming
#stemming reduces words to their root form.

from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

words = ["playing","studies","running","gone","watched","coding"]
for w in words:
  print(stemmer.stem(w))
# Out:
# play
# studi
# run
# gone
# watch
# code

# %%
#Lemmatization
#Lemmatization converts words to their dictionary form

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

print(lemmatizer.lemmatize("writing"))
print(lemmatizer.lemmatize("studies"))
print(lemmatizer.lemmatize("best"))
print(lemmatizer.lemmatize("running"))
print(lemmatizer.lemmatize("coding"))
print(lemmatizer.lemmatize("better"))
# Out:
# writing
# study
# best
# running
# coding
# better

# %%
#Part-of-speech(POS) Tagging
#POS tagging identifies grammatical roles of words.
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk import pos_tag

words= word_tokenize("Python is a powerful programing language")
pos_tags1 = pos_tag(words)

print(pos_tags1)

# NN = proper noun
# VBZ = verb
# DT = determiner
# JJ = adjective
# Out:
# [('Python', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('powerful', 'JJ'), ('programing', 'NN'), ('language', 'NN')]

# %%
#Word Frequency count
from nltk.probability import FreqDist

words = word_tokenize(text)
fd = FreqDist(words)

print(fd.most_common())
# Out:
# [('is', 2), ('.', 2), ('Python', 1), ('easy', 1), ('It', 1), ('widely', 1), ('used', 1), ('in', 1), ('data', 1), ('science', 1)]
